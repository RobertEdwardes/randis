# %%
import pandas as pd
import geopandas as gpd
import sys
import asyncio
from fileBuild import adjGraph, CensusBlockTable, fileDescription

# %%
geo ='C:\\Users\\Robbie Remote PC\\Documents\\Github-Build\\randis\\PL\\algeo2010.pl'
pl ='C:\\Users\\Robbie Remote PC\\Documents\\Github-Build\\randis\\PL\\al000012010.pl'
shp = 'tl_2019_01_bg.shp'
file = CensusBlockTable(geo, pl, shp, 'sample')
# Out:
# PLGEO Loaded
# PL1 Loaded
# C:\Users\Robbie Remote PC\Documents\Github-Build\randis\fileBuild.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PLGEOSimp['GEOID'] = PLGEOSimp['state'].fillna('') + PLGEOSimp['county'].fillna('')  + PLGEOSimp['tract'].fillna('')  + PLGEOSimp['blkgrp'].fillna('')
# shp_file Loaded

# %%
file.head()
# Out:
#     logrec region division state county ctycc ctysc cousub cousubcc cousubsc  \
# 0  0014601      3        6    01    001    H1   NaN    NaN      NaN      NaN
# 1  0016257      3        6    01    001    H1   NaN  92628       Z5      NaN
# 2  0016258      3        6    01    001    H1   NaN  92628       Z5      NaN
# 3  0016259      3        6    01    001    H1   NaN  92628       Z5      NaN
# 4  0016260      3        6    01    001    H1   NaN  92628       Z5      NaN
#
#    ... TRACTCE BLKGRPCE       NAMELSAD  MTFCC FUNCSTAT    ALAND AWATER  \
# 0  ...  020100        1  Block Group 1  G5030        S  4259428  28435
# 1  ...  020100        1  Block Group 1  G5030        S  4259428  28435
# 2  ...  020100        1  Block Group 1  G5030        S  4259428  28435
# 3  ...  020100        1  Block Group 1  G5030        S  4259428  28435
# 4  ...  020100        1  Block Group 1  G5030        S  4259428  28435
#
#       INTPTLAT      INTPTLON  \
# 0  +32.4658320  -086.4896607
# ...

# %%
adjGraph(file, 'sample')
# Out:
# 0.0003738918779467354%
# 0.0007477837558934708%
# 0.0011216756338402062%
# 0.0014955675117869415%
# 0.0018694593897336767%
# 0.0022433512676804123%
# 0.0026172431456271475%
# 0.002991135023573883%
# 0.003365026901520618%
# 0.0037389187794673534%
# 0.004112810657414089%
# 0.004486702535360825%
# 0.00486059441330756%
# 0.005234486291254295%
# 0.005608378169201031%
# 0.005982270047147766%
# 0.006356161925094501%
# 0.006730053803041236%
# 0.007103945680987971%
# 0.007477837558934707%
# 0.007851729436881442%
# 0.008225621314828178%
# 0.008599513192774914%
# 0.00897340507072165%
# 0.009347296948668385%
# 0.00972118882661512%
# 0.010095080704561856%
# 0.01046897258250859%
# 0.010842864460455326%
# 0.011216756338402061%
# 0.011590648216348797%
# 0.011964540094295532%
# 0.012338431972242268%
# 0.012712323850189002%
# 0.013086215728135737%
# 0.013460107606082471%
# 0.013833999484029209%
# 0.014207891361975943%
# 0.01458178323992268%
# 0.014955675117869414%
# 0.01532956699581615%
# ...
